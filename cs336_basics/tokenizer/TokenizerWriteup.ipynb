# %%
chr(0)
# Out:
# '\x00'

# %% [markdown]
# ## The Unicode character 0 returns `\x00' bytes.

# %%
"this is a test " + chr(0) + "string"
# Out:
# 'this is a test \x00string'

# %%
test_string = "hello readers of the world こんにちは!"
utf8_encode = test_string.encode("utf-8")
print(utf8_encode)
# Out:
# b'hello readers of the world \xe3\x81\x93\xe3\x82\x93\xe3\x81\xab\xe3\x81\xa1\xe3\x81\xaf!'

# %%
print(list(utf8_encode))
# Out:
# [104, 101, 108, 108, 111, 32, 114, 101, 97, 100, 101, 114, 115, 32, 111, 102, 32, 116, 104, 101, 32, 119, 111, 114, 108, 100, 32, 227, 129, 147, 227, 130, 147, 227, 129, 171, 227, 129, 161, 227, 129, 175, 33]

# %% [markdown]
# ##
